# %% [markdown]
# # Script to prepare data from simulation
# This script is used to prepare data for tensor SVD denoising from simulatons. Poisson noise and finite source size are included in the dataset. Denoised data can be compared to the ground truth with no noise.

# %%
import os
import scipy.io as sio
import scipy.misc as smisc
import numpy as np
import re as regexp
import math
import matplotlib.pyplot as plt
import scipy

# %%
def gaussKernel(sigma,imsize):
    x,y = np.meshgrid(range(1,imsize+1),range(1,imsize+1))
    x = x - imsize//2
    y = y - imsize//2
    tmp = -(x**2+y**2)/(2*sigma**2)
    return (1/(2*np.pi*sigma**2))*np.exp(tmp)

# %%
# Gloabl parameter setup
# path for CBEDs, start with unconvoluted ones, tile, then do convolution. Tiling artifact can be avoided in this way.
path = '/srv/home/chenyu/TensorDenoise/Simulatons/STO_simulation/scratch/0.0_0.0mrad/'
slc = 5
rep_x = 7
rep_y = 7
base_name = 'depth0_slice'+str(slc)
base_ext = '_FPavg.npy'
array_size = (41,41)  # real space array size for single unit cell

# %%
imsize = (np.load(path+base_name+'_X0_Y0'+base_ext)).shape
out_sz = array_size + imsize
output = np.zeros(out_sz,dtype=np.float32)
for x in range(array_size[0]):
        for y in range(array_size[1]):
            output[x,y,:,:] = np.load(path+base_name+'_X'+str(x)+'_Y'+str(y)+base_ext)
output = np.squeeze(output)
output = output / 17  # for 17 phonons used

# tile the unconvoluted array
output_crop = output[9:31,9:31,:,:]  # crop the original datacube to have one unit cell
output_tile = np.tile(output_crop,(rep_x,rep_y,1,1))

# generate convolution kernel
source_size = 110
px_size = 17.5
sigma = (source_size/px_size)/(2.355)
kernel = gaussKernel(sigma,output_tile.shape[0])
fkernel = np.fft.fft2(kernel)

# Gaussian convolution with FFT
kx,ky = output_tile.shape[2:4]
#initialize result array
result = np.zeros(output_tile.shape,dtype=np.float32)
for k in range(kx):
    for l in range(ky):
        #apply convolution for each pixel in (kx,ky) over the whole set of images in (x,y)
        result[:,:,k,l] = np.fft.fftshift(np.fft.ifft2(fkernel*np.fft.fft2(output_tile[:,:,k,l]))).real

print(result.shape)
# Out:
# (154, 154, 328, 328)

# %%
plt.figure(figsize=(16,8))
plt.subplot(121)
plt.imshow(result[:,:,10,10])
plt.colorbar()

plt.subplot(122)
plt.imshow(result[10,10,:,:])
plt.colorbar()

# %%
# crop 4D dataset to 128x128 in k-space
# Use 114x114 in real space to get the same size as Si edge dislocation simulation
datacube_cropped = result[0:114,0:114,100:228,100:228]
current = 18.9 # beam current in pA
FPS_list = [1000,2000,4000,6000,8000,10000,20000,40000]

for i in range(len(FPS_list)):
    FPS = FPS_list[i]

# Save truth in unit of electrons, in 3D stack
    datacube_truth = np.zeros((datacube_cropped.shape[0],datacube_cropped.shape[1],datacube_cropped.shape[2]*datacube_cropped.shape[3]))
    for i in range(datacube_cropped.shape[2]):
        for j in range(datacube_cropped.shape[3]):
            datacube_truth[:,:,i*datacube_cropped.shape[3]+j] = datacube_cropped[:,:,i,j]*current/1.6/FPS*10000000
    np.save('/srv/home/chenyu/TensorDenoise/Simulatons/STO_simulation\
/Simulation_truth_STO_slice_'+str(slc)+'_'+str(FPS)+'FPS_fullsize.npy',datacube_truth)

    # Add noise after rescale dataset to number of electrons
    datacube_noisy = np.zeros(datacube_truth.shape,dtype=np.uint8)
    for i in range(datacube_truth.shape[2]):
        frame = datacube_truth[:,:,i]
        datacube_noisy[:,:,i] = np.random.poisson(frame).astype('int')

    # save noisy datacube in .mat file
    adict = {}
    adict['datacube'] = datacube_noisy
    sio.savemat('/srv/home/chenyu/TensorDenoise/Simulatons/STO_simulation\
/Simulation_noisy_STO_slice_'+str(slc)+'_'+str(FPS)+'FPS_fullsize',adict)

# %%
print(np.sum(datacube_cropped))
print(datacube_cropped.shape)
# Out:
# 20919.773
# (150, 150, 128, 128)

# %%
current = 18.9 # beam current in pA
FPS_list = [1000,2000,4000,6000,8000,10000,20000,40000]
# crop 4D dataset to 10x10 in k-space for comparison between NLPCA and tensor SVD
datacube_cropped = result[0:114,0:114,159:169,159:169]

for i in range(len(FPS_list)):
    FPS = FPS_list[i]
    # Save truth in unit of electrons, in 3D stack
    datacube_truth = np.zeros((datacube_cropped.shape[0],datacube_cropped.shape[1],datacube_cropped.shape[2]*datacube_cropped.shape[3]))
    for i in range(datacube_cropped.shape[2]):
        for j in range(datacube_cropped.shape[3]):
            datacube_truth[:,:,i*datacube_cropped.shape[3]+j] = datacube_cropped[:,:,i,j]*current/1.6/FPS*10000000
    np.save('/srv/home/chenyu/TensorDenoise/Simulatons/STO_simulation\
/Simulation_truth_STO_slice_'+str(slc)+'_'+str(FPS)+'FPS_cropped_100layers.npy',datacube_truth)

    # Add noise after rescale dataset to number of electrons
    datacube_noisy = np.zeros(datacube_truth.shape,dtype=np.uint8)
    for i in range(datacube_truth.shape[2]):
        frame = datacube_truth[:,:,i]
        datacube_noisy[:,:,i] = np.random.poisson(frame).astype('int')

    # save noisy datacube in .mat file
    adict = {}
    adict['datacube'] = datacube_noisy
    sio.savemat('/srv/home/chenyu/TensorDenoise/Simulatons/STO_simulation\
/Simulation_noisy_STO_slice_'+str(slc)+'_'+str(FPS)+'FPS_cropped_100layers',adict)

# %%
plt.figure(figsize=(15,4))

plt.subplot(131)
temp = np.sum(np.sum(result,axis=2),axis=2)
plt.imshow(temp)

plt.subplot(132)
temp = np.sum(datacube_noisy,axis=2)
plt.imshow(temp)
plt.colorbar()

plt.subplot(133)
plt.imshow(datacube_noisy[23,23,:,:])
plt.colorbar()

# %%
datacube_noisy_cropped = datacube_noisy[8:30,8:30,:,:]
datacube_tiled = np.tile(datacube_noisy_cropped,(2,2,1,1))
temp = np.sum(np.sum(datacube_tiled,axis=2),axis=2)
plt.imshow(temp)
print(datacube_tiled.shape)
# Out:
# (44, 44, 128, 128)

# %%
datacube_denoised = sio.loadmat('/srv/home/chenyu/TensorDenoise/Simulatons/Simulation_STO_7x7uc_denoised.mat')
datacube_denoised = datacube_denoised['est_HOOI']
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-3-a67b586e1e68> in <module>()
# ----> 1 datacube_denoised = sio.loadmat('/srv/home/chenyu/TensorDenoise/Simulatons/Simulation_STO_7x7uc_denoised.mat')
#       2 datacube_denoised = datacube_denoised['est_HOOI']
#
# ~/anaconda/lib/python3.6/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     140     variable_names = kwargs.pop('variable_names', None)
#     141     MR, file_opened = mat_reader_factory(file_name, appendmat, **kwargs)
# --> 142     matfile_dict = MR.get_variables(variable_names)
#     143     if mdict is not None:
#     144         mdict.update(matfile_dict)
#
# ~/anaconda/lib/python3.6/site-packages/scipy/io/matlab/mio4.py in get_variables(self, variable_names)
#     398                 self.mat_stream.seek(next_position)
#     399                 continue
# --> 400             mdict[name] = self.read_var_array(hdr)
#     401             self.mat_stream.seek(next_position)
#     402             if variable_names is not None:
#
# ~/anaconda/lib/python3.6/site-packages/scipy/io/matlab/mio4.py in read_var_array(self, header, process)
#     373            `process`.
#     374         '''
# --> 375         return self._matrix_reader.array_from_header(header, process)
#     376
#     377     def get_variables(self, variable_names=None):
#
# ~/anaconda/lib/python3.6/site-packages/scipy/io/matlab/mio4.py in array_from_header(self, hdr, process)
#     135         mclass = hdr.mclass
#     136         if mclass == mxFULL_CLASS:
# --> 137             arr = self.read_full_array(hdr)
#     138         elif mclass == mxCHAR_CLASS:
#     139             arr = self.read_char_array(hdr)
#
# ~/anaconda/lib/python3.6/site-packages/scipy/io/matlab/mio4.py in read_full_array(self, hdr)
#     205             res_j = self.read_sub_array(hdr, copy=False)
#     206             return res + (res_j * 1j)
# --> 207         return self.read_sub_array(hdr)
#     208
#     209     def read_char_array(self, hdr):
#
# ~/anaconda/lib/python3.6/site-packages/scipy/io/matlab/mio4.py in read_sub_array(self, hdr, copy)
#     171         for d in dims:
#     172             num_bytes *= d
# --> 173         buffer = self.mat_stream.read(int(num_bytes))
#     174         if len(buffer) != num_bytes:
#     175             raise ValueError("Not enough bytes to read matrix '%s'; is this "
#
# MemoryError:

# %%
plt.figure(figsize=(15,4))

i = 10
j = 15
plt.subplot(131)
plt.imshow(datacube_denoised[:,:,i*41+j])
plt.colorbar()
plt.axis('off')
plt.subplot(132)
plt.imshow(datacube_final[:,:,i*41+j])
plt.colorbar()
plt.axis('off')
plt.subplot(133)
plt.imshow(datacube_truth[:,:,i*41+j])
plt.colorbar()
plt.axis('off')
# Out:
# (-0.5, 43.5, 43.5, -0.5)

# %%
# load dataset larger than 2GB saved by Matlab, in hdf5 format
import h5py
path ='/srv/home/chenyu/TensorDenoise/Simulatons/'
arrays = {}
f = h5py.File(path + 'Simulation_STO_7x7uc_denoised.mat')
for k, v in f.items():
    arrays[k] = np.array(v)
arrays = arrays['est_HOOI']
# Out:
# /srv/home/chenyu/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   """
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     198         try:
# --> 199             fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     200         except IOError:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     201             try:
# --> 202                 fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#     203             except IOError:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-050099c75d7c> in <module>()
#       3 path ='/srv/home/chenyu/TensorDenoise/Simulatons/'
#       4 arrays = {}
# ----> 5 f = h5py.File(path + 'Simulation_STO_7x7uc_denoised.mat')
#       6 for k, v in f.items():
#       7     arrays[k] = np.array(v)
#
# ~/anaconda/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# ~/anaconda/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     202                 fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#     203             except IOError:
# --> 204                 fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     205     else:
#     206         raise ValueError("Invalid mode; must be one of r, r+, w, w-, x, a")
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = '/srv/home/chenyu/TensorDenoise/Simulatons/Simulation_STO_7x7uc_denoised.mat', errno = 17, error message = 'File exists', flags = 15, o_flags = c2)
