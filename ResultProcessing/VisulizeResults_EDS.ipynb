# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import h5py
import matplotlib.patches as patches
from numpy import *
from PIL import Image
import glob
# Out:
# C:\Users\Chenyu\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Analysis eigenvalues from raw data with 240x244x1000
temp = sio.loadmat('E:\Denoising_Rungang\EDSdata\EDS_eigenvalues.mat')

fig = plt.figure(figsize=(14,5))

fig.add_subplot(131)
e1 = temp['e1']
e1 = e1[::-1]
plt.plot(np.log(e1[0:10]),linewidth='2')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.axvline(x=35,color='r',ls='--')
plt.ylabel('log(Eigenvalues)',fontsize=14)
plt.xlabel('Components',fontsize=14)

fig.add_subplot(132)
e2 = temp['e2']
e2 = e2[::-1]
plt.plot(np.log(e2[0:10]),linewidth='2')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.axvline(x=38,color='r',ls='--')
# plt.ylabel('Eigenvalues',fontsize=14)
plt.xlabel('Components',fontsize=14)

fig.add_subplot(133)
e3 = temp['e3']
e3 = e3[::-1]
plt.plot(np.log(e3[:1000]),linewidth='2')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.axvline(x=200,color='r',ls='--')
# plt.ylabel('Eigenvalues',fontsize=14)
plt.xlabel('Components',fontsize=14)
# Out:
# Text(0.5, 0, 'Components')

# %%
# Analysis eigenvalues from raw data with 240x244x7 channels
temp = sio.loadmat('E:\Denoising_Rungang\EDSdata\EDS_grouped_eigenvalues.mat')

fig = plt.figure(figsize=(14,5))

fig.add_subplot(131)
e1 = temp['e1']
e1 = e1[::-1]
plt.plot(np.linspace(1,20,20),np.log(e1[0:20]),'o',linewidth='2')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.axvline(x=35,color='r',ls='--')
plt.ylabel('log(Eigenvalues)',fontsize=14)
plt.xlabel('Components',fontsize=14)

fig.add_subplot(132)
e2 = temp['e2']
e2 = e2[::-1]
plt.plot(np.linspace(1,20,20),np.log(e2[0:20]),'o',linewidth='2')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.axvline(x=38,color='r',ls='--')
# plt.ylabel('Eigenvalues',fontsize=14)
plt.xlabel('Components',fontsize=14)

fig.add_subplot(133)
e3 = temp['e3']
e3 = e3[::-1]
plt.plot(np.linspace(1,7,7),np.log(e3),'o',linewidth='2')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.axvline(x=200,color='r',ls='--')
# plt.ylabel('Eigenvalues',fontsize=14)
plt.xlabel('Components',fontsize=14)
# Out:
# Text(0.5, 0, 'Components')

# %%
# Analysis denoise results from grouped EDS data
temp = sio.loadmat('E:\Denoising_Rungang\EDSdata\EDS_denoised_grouped_10-10-7.mat')
denoised = temp['est_HOOI']
temp = sio.loadmat('E:\Denoising_Rungang\EDSdata\EDS_grouped.mat')
noisy = temp['datacube']
temp = sio.loadmat('E:\Denoising_Rungang\EDSdata\EDS_NLPCA_grouped_17-10-10.mat')
NLPCA = temp['est_NLPCA']

# %%
fig = plt.figure(figsize=(15,20))

data = noisy[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)

fig.add_subplot(431)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255*4
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.title('Ca',fontsize=24)
plt.ylabel('Noisy',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(432)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.title('Ti',fontsize=24)
plt.axis('off')

fig.add_subplot(433)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')
plt.title('Nd',fontsize=24)

data = denoised[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)

fig.add_subplot(434)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.ylabel('Tensor SVD',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(435)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.add_subplot(436)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

data = NLPCA[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)

fig.add_subplot(437)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.ylabel('NLPCA',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(438)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.add_subplot(439)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

data = CPCA[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)

fig.add_subplot(4,3,10)
layer = data[:,:,0]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.ylabel('Conventional PCA',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(4,3,11)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.add_subplot(4,3,12)
layer = data[:,:,2]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.subplots_adjust(wspace = 0.0, hspace = 0.1)
fig.savefig('E:/Denoising_Rungang/EDSdata/Overall_results.tif')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fdfe94d1b025> in <module>()
#     103 plt.axis('off')
#     104
# --> 105 data = CPCA[:]
#     106 data = data / np.amax(data) * 255
#     107 rgbArray = np.zeros([240,244,3],dtype=np.uint8)
#
# NameError: name 'CPCA' is not defined

# %%
# Reconstruct data from previous CPCA results, use first six components from 700 channels
path = 'E:/Denoising_Rungang/EDSdata/CPCA/Recon_0-5_from20/*.tif'
files = glob.glob(path)
datacube = np.zeros((256,256,len(files)))
for ifile in range(len(files)):
    im = Image.open(files[ifile])
    im = np.asarray(im)
    datacube[:,:,ifile] = im

# %%
plt.plot(np.sum(np.sum(datacube,axis=0),axis=0))
plt.axvline(x=680)
CPCA = np.zeros((256,256,3))
CPCA[:,:,0] = np.transpose(np.sum(datacube[:,:,300:470],axis=2))
CPCA[:,:,1] = np.transpose(np.sum(datacube[:,:,470:590],axis=2))
CPCA[:,:,2] = np.transpose(np.sum(datacube[:,:,590:680],axis=2))
CPCA = CPCA[-241:-1,5:249,:] # Roughly crop the data to have same viewing region as registered and cropped datacube

# %%
plt.imshow(np.transpose(CPCA[:,:,0]))

# %%
# Results from higher ranks along real space dimensions
fig = plt.figure(figsize=(20,8))

temp = sio.loadmat('E:\Denoising_Rungang\EDSdata\EDS_grouped.mat')
noisy = temp['datacube']

fig.add_subplot(3,7,7)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*4
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')
plt.title('Noisy',fontsize=16)

fig.add_subplot(3,7,14)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.add_subplot(3,7,21)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

rank_list = [4,7,10,15,20,30]
for irank in range(len(rank_list)):
    rank = rank_list[irank]
    path = 'E:\Denoising_Rungang\EDSdata\EDS_denoised_grouped_'+str(rank)+'-'+str(rank)+'-7.mat'
    temp = sio.loadmat(path)
    denoised = temp['est_HOOI']
    data = denoised[:]
    data = data / np.amax(data) * 255
    
    # Ca map
    fig.add_subplot(3,7,irank+1)
    layer = data[:,:,1]
    layer = layer/np.amax(layer)*255
    rgbArray = np.zeros([240,244,3],dtype=np.uint8)
    rgbArray[:,:,2] = layer.astype('int')
    img = Image.fromarray(rgbArray)
    plt.imshow(img)
    plt.title('Rank='+str(rank),fontsize=16)
    plt.axis('off')
    
    # Ti map
    fig.add_subplot(3,7,irank+1+7)
    layer = data[:,:,2] + data[:,:,3]
    layer = layer/np.amax(layer)*255
    rgbArray = np.zeros([240,244,3],dtype=np.uint8)
    rgbArray[:,:,0] = layer.astype('int')
    img = Image.fromarray(rgbArray)
    plt.imshow(img)
    plt.axis('off')
    
    # Nd map
    fig.add_subplot(3,7,irank+1+14)
    layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
    layer = layer/np.amax(layer)*255
    rgbArray = np.zeros([240,244,3],dtype=np.uint8)
    rgbArray[:,:,1] = layer.astype('int')
    img = Image.fromarray(rgbArray)
    plt.imshow(img)
    plt.axis('off')
    
fig.subplots_adjust(wspace = 0.05, hspace = 0.05)

# %%
# Test channel-wise normalization according to suggestion from reviewer #2

temp = sio.loadmat('D:/2020/TensorSVD/ManuscriptRelated/ExperimentData/TensorDenoised/EDS_denoised_grouped_10-10-7_channel_normed.mat')
denoised = temp['est_HOOI']
temp = sio.loadmat('D:/2020/TensorSVD/ManuscriptRelated/ExperimentData/RawData/EDS_grouped.mat')
noisy = temp['datacube']

fig = plt.figure(figsize=(15,20))

data = noisy[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)

fig.add_subplot(431)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255*4
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.title('Ca',fontsize=24)
plt.ylabel('Noisy',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(432)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.title('Ti',fontsize=24)
plt.axis('off')

fig.add_subplot(433)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')
plt.title('Nd',fontsize=24)

data = denoised[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)

fig.add_subplot(434)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.ylabel('Tensor SVD',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(435)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.add_subplot(436)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.savefig('C:/Users/Chenyu/OneDrive - UW-Madison/Manuscripts/Submitted/Zhang_Denoise_2020/Ultramicroscopy submission/\
EDS denoise channel norm.tif')

# %%
# Test denoise result on simulated results according to suggestions from reviewer #1's suggestion

temp = sio.loadmat('D:/2020/TensorSVD/ManuscriptRelated/SimulationData/EDS_simulation/Simulation_denoised_50%Ca_rescaled.mat')
denoised = temp['est_HOOI']
temp = sio.loadmat('D:/2020/TensorSVD/ManuscriptRelated/SimulationData/EDS_simulation/Simulation_noisy_50%Ca_rescaled.mat')
noisy = temp['datacube']
temp = sio.loadmat('D:/2020/TensorSVD/ManuscriptRelated/SimulationData/EDS_simulation/Simulation_NLPCA_50%Ca_rescaled.mat')
NLPCA = temp['est_NLPCA']
temp = sio.loadmat('D:/2020/TensorSVD/ManuscriptRelated/SimulationData/EDS_simulation/Simulation_noiseless_50%Ca_rescaled.mat')
truth = temp['datacube']

# %%
fig = plt.figure(figsize=(15,20))

data = noisy[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)

fig.add_subplot(431)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255*4
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.title('Ca',fontsize=24)
plt.ylabel('Noisy',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(432)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.title('Ti',fontsize=24)
plt.axis('off')

fig.add_subplot(433)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')
plt.title('Nd',fontsize=24)

data = denoised[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([240,244,3],dtype=np.uint8)

fig.add_subplot(434)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.ylabel('Tensor SVD',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(435)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.add_subplot(436)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')


data = NLPCA[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)

fig.add_subplot(437)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.ylabel('NLPCA',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(438)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.add_subplot(439)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')


data = truth[:]
data = data / np.amax(data) * 255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)

fig.add_subplot(4,3,10)
layer = data[:,:,1]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,2] = layer.astype('int')*1
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.ylabel('Truth',fontsize=24)
plt.xticks([])
plt.yticks([])

fig.add_subplot(4,3,11)
layer = data[:,:,2] + data[:,:,3]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,0] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')

fig.add_subplot(4,3,12)
layer = data[:,:,4] + data[:,:,5] + data[:,:,6]
layer = layer/np.amax(layer)*255
rgbArray = np.zeros([256,256,3],dtype=np.uint8)
rgbArray[:,:,1] = layer.astype('int')
img = Image.fromarray(rgbArray)
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)
